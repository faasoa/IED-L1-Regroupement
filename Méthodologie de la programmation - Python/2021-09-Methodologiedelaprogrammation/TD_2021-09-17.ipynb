# %% [markdown]
# - Nom         :
# - Prénom      :
# - N. étudiant :

# %% [markdown]
# > Vous pouvez réaliser les exercices directement sur jupyter et rendre le fichier .ipynb modifié par vos
# soins. Alternativement, vous pouvez rendre l’exercice directement en python (fichier .py).
# >
# > Dans tous les cas, pensez bien à indiquer votre **nom**, **prénom** et **n. d’étudiant**.
# >
# > Vous devrez envoyer votre travail (exercice et fichier de sortie) sur le mail
# josue.melka02@univ-paris8.fr. Tout travail rendu après le délai fixé ne sera pas pris en compte.
# >
# > _(**Note**: il n'est pas permis d'utiliser numpy pour resoudre ces questions)_

# %% [markdown]
# # TD python - 17 septembre 2021

# %% [markdown]
# Dans le cadre de l'épidémie de Covid-19, le gouvernement met à disposition quantité de données en [Open Data](https://www.data.gouv.fr/fr/pages/donnees-coronavirus/), qui permettent par exemple d'alimenter des sites de suivi en ligne comme [CovidTracker](https://covidtracker.fr/).
#
# Pour cet exercice, nous allons travailler sur une version simplifiée du fichier national de vaccination ([source](https://www.data.gouv.fr/fr/datasets/donnees-relatives-aux-personnes-vaccinees-contre-la-covid-19-1/)), sous la forme du fichier CSV `vac-20210916.csv` se présentant comme suit:
#
# ```
# jour,n_dose1,n_complet
# 2020-12-27,348,4
# 2020-12-28,354,1
# 2020-12-29,250,0
# 2020-12-30,292,1
# 2020-12-31,230,0
# 2021-01-01,265,3
# 2021-01-02,213,4
# 2021-01-03,248,1
# 2021-01-04,1739,9
# 2021-01-05,5670,23
# ...
# ```
#
# Les lignes comportent des éléments (colonnes) séparés par des virgules.
#
# - la 1ere colonne indique la date
# - la 2e colonne indique le nombre de 1ere doses effectuées ce jour là
# - la 3e colonne indique le nombre de doses complètes effectuées ce jour là

# %% [markdown]
# ## Lecture du fichier
#
#
# Ecrire une fonction `lire_csv(filename)` permettant de lire et retourner le contenu du fichier `vac-20210916.csv` sous la forme d'une liste de tuples.
#
# > _Pensez à convertir les colonnes de nombres en `int`, et sauter la première ligne qui contient uniquement le nom des colonnes._
#
# Par exemple, le début du retour pour `lire_csv('vac-20210916.csv')` sera :
# ```
# [('2020-12-27', 348, 4),
#  ('2020-12-28', 354, 1),
#  ('2020-12-29', 250, 0),
#  ('2020-12-30', 292, 1),
#  ('2020-12-31', 230, 0),
#  ('2021-01-01', 265, 3),
#  ('2021-01-02', 213, 4),
#  ('2021-01-03', 248, 1),
#  ('2021-01-04', 1739, 9),
#  ('2021-01-05', 5670, 23),
#  ...
# ]
# ```

# %%
def lire_csv(filename):
    # votre code ici

# %% [markdown]
# ## Extraction de colonne
#
# Ecrire une fonction `colonne(tableau, n)` permettant d'extraire la colonne `n` du tableau.
#
# Par exemple, `colonne(tab, 1)` renverra:
# ```
# [348,
#  354,
#  250,
#  292,
#  230,
#  265,
#  213,
#  248,
#  1739,
#  5670,
#  ...
# ]
# ```

# %%
def colonne(tableau, n):
    # votre code ici

# %% [markdown]
# ## Recherche de maximum
#
# Ecrire une fonction `max_col(tableau, n)` permettant de retourner l'**indice** et la **valeur** maximale d'une colonne `n` donnée dans le tableau créé à l'exercice precedent.
#
# Par exemple, `max_col(tabl, 1)` retournera `(144, 503698)`

# %%
def max_col(tableau, n):
    # votre code ici

# %% [markdown]
# ## Cumul des doses
#
# On souhaite ajouter de nouvelles colonnes contenant le cumul des doses des colonnes 1 et 2.
#
# Ecrire une fonction `cumul(tableau, n)` permettant de calculer la somme cumulée pour une colonne donnée.
#
# Par exemple, le début de `cumul(tab, 1)` sera:
# ```
# [348,
#  702,
#  952,
#  1244,
#  1474,
#  1739,
#  1952,
#  2200,
#  3939,
#  9609,
#  ...
# ]
# ```

# %%
def cumul(tableau, n):
    # votre code ici

# %% [markdown]
# ## Moyenne glissante
#
# Afin de lisser les disparités de la courbe d'une valeur dues aux écarts entre jours ouvrés et weekend, il est courant d'utiliser une moyenne glissante sur 7 jours. Cela correspond simplement à prendre pour chaque jour (sauf les 6 premiers) la moyenne des 7 derniers jours.
#
# Visuellement, cela donne ceci :
#
# ![Exemple](data:image/png;base64,...)
#
# Ecrire une fonction `moyenne_glissante(lst, k)` qui calcule la moyenne glissante des valeurs de `lst` avec une fenêtre de `k` valeurs.
#
# Par exemple, `moyenne_glissante(colonne(tableau, 1), 7)` retournera:
#
# ```
# [278.85714285714283,
#  264.57142857142856,
#  462.42857142857144,
#  1236.7142857142858,
#  2850.4285714285716,
#  6965.142857142857,
#  12170.142857142857,
#  13720.42857142857,
#  14506.714285714286,
#  19918.0,
#  ...
# ]
# ```

# %%
def moyenne_glissante(lst, k):
    # votre code ici
